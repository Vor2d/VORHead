# %%
from matplotlib.pyplot import *
from matplotlib import pyplot
import math
from scipy.optimize import *
import numpy

# %%
file_dir = "./data/"

# %%
class Section:
    
    def __init__(self,mode):
        self.mode = mode
        self.AZ_RW_dir = []
        self.delay_RW = []
        self.move_target = []
        self.AZ_percent = {}
        
    def cal_ac(self):
        AZ_RI_TO = {}
        for ARD in self.AZ_RW_dir:
            if(ARD[0] in AZ_RI_TO):
                AZ_RI_TO[ARD[0]][1] += 1
            else:
                AZ_RI_TO[ARD[0]] = [0,1]
            if(ARD[1] == 1):
                AZ_RI_TO[ARD[0]][0] += 1
        for ART in AZ_RI_TO.keys():
            self.AZ_percent[ART] = float(AZ_RI_TO[ART][0]) / float(AZ_RI_TO[ART][1])

# %%
def read_file(AF_name, DF_name,sectionN = 0):
    file = open(file_dir+AF_name,"r")
    lines = file.readlines()
    
    section = Section("")
    
    start_flag = False
    S_index = 0
    last_delay = 0.0
    for line in lines:
        strings = line.split()
        if(len(strings)<1):
            continue
        if(strings[1] == "start"):
            if(S_index == sectionN):
                start_flag = True
                section.mode = strings[4]
            else:
                start_flag = False
            S_index += 1
        if(start_flag):
            try:
                AZ = int(strings[3])
            except:
                AZ = -100
            if(AZ >= 0):
                RW = 1 if (strings[4] == "True") else 0
                section.AZ_RW_dir.append((AZ,RW,strings[5]))
                section.delay_RW.append((last_delay,RW))
            if(AZ == -2):
                try:
                    last_delay = float(strings[4])
                except:
                    last_delay = -1.0
    file.close()
    
    file = open(file_dir+DF_name,"r")
    lines = file.readlines()
    for line in lines:
        strings = line.split()
        if(len(strings)<1):
            continue
        if(strings[4] == "MoveTarget"):
            try:
                simS = int(strings[2])
                degree = float(strings[5]) if (strings[6] == "1") else -(float(strings[5]))
            except:
                simS = int(-1)
                degree = 0.0
            section.move_target.append((simS,degree))
            
            
    return section

# %%
section = read_file("AcuityLog_2019_08_30_02_09_54.txt","JumpLog__2019_08_30_02_25_56_2.txt",sectionN = 0)
print(section.mode)
for a in section.AZ_RW_dir:
    print(a)
#for a in section.delay_RW:
    #print(a)
#for a in section.move_target:
    #print(a)
section.cal_ac()
for a in section.AZ_percent.keys():
    print(a,section.AZ_percent[a])
# Out:
# StaticAcuity
# (3, 1, 'down')
# (4, 1, 'uple')
# (2, 1, 'left')
# (3, 1, 'right')
# (3, 1, 'dori')
# (0, 1, 'dole')
# (6, 1, 'up')
# (0, 1, 'dori')
# (7, 1, 'uple')
# (1, 1, 'uple')
# (7, 1, 'up')
# (1, 1, 'upri')
# (5, 1, 'down')
# (3, 1, 'right')
# (4, 1, 'upri')
# (8, 1, 'left')
# (6, 1, 'down')
# (8, 1, 'down')
# (8, 1, 'dori')
# (7, 1, 'dori')
# (6, 1, 'dole')
# (7, 1, 'right')
# (5, 1, 'upri')
# (3, 1, 'left')
# (0, 1, 'uple')
# (9, 1, 'left')
# (4, 1, 'left')
# (6, 1, 'right')
# (8, 1, 'dori')
# (8, 1, 'dori')
# (9, 1, 'uple')
# (4, 1, 'right')
# (3, 1, 'left')
# (1, 1, 'right')
# (4, 1, 'upri')
# (5, 1, 'dole')
# (8, 1, 'dole')
# (1, 1, 'left')
# (5, 1, 'upri')
# (6, 1, 'upri')
# (6, 1, 'left')
# (0, 0, 'down')
# (7, 1, 'uple')
# (9, 1, 'left')
# (9, 1, 'down')
# (9, 1, 'dori')
# (6, 1, 'left')
# (8, 1, 'left')
# (0, 1, 'uple')
# (5, 0, 'upri')
# (5, 1, 'down')
# (3, 1, 'left')
# (2, 1, 'upri')
# (2, 1, 'right')
# (5, 1, 'down')
# (4, 1, 'dori')
# (7, 1, 'up')
# (3, 1, 'down')
# (5, 1, 'up')
# (2, 1, 'down')
# (6, 1, 'up')
# (9, 1, 'upri')
# (5, 1, 'dori')
# (9, 1, 'upri')
# (2, 1, 'up')
# (4, 1, 'dole')
# (2, 1, 'dori')
# (4, 1, 'dole')
# (1, 1, 'up')
# (8, 1, 'uple')
# (0, 1, 'uple')
# (3, 1, 'down')
# (9, 1, 'upri')
# (7, 1, 'left')
# (2, 1, 'left')
# (7, 1, 'upri')
# (0, 1, 'dori')
# (0, 1, 'uple')
# (1, 1, 'down')
# (9, 1, 'right')
# (8, 1, 'down')
# (2, 1, 'dori')
# (4, 1, 'right')
# (1, 1, 'upri')
# (0, 1, 'upri')
# (7, 1, 'upri')
# (2, 1, 'up')
# (6, 1, 'right')
# (1, 1, 'dole')
# (1, 1, 'right')
# 3 1.0
# 4 1.0
# 2 1.0
# 0 0.8888888888888888
# 6 1.0
# 7 1.0
# 1 1.0
# 5 0.8888888888888888
# 8 1.0
# 9 1.0

# %%
def plot_ac(section):
    x_data =
